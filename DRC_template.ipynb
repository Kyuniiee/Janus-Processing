# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate
from scipy import stats
import scipy.optimize as optimization
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.ticker import ScalarFormatter
import pandas as pd

xdata = np.array([10,3.3,1.1,0.3,0.1,0.03])
ydata = np.array([591, 648.5, 714.75, 941, 1226, 1768.25, 
                  2232.25, 2716.25, 3056.25, 3034.5])
ydata2 = np.array([595.5, 711, 898.25, 2215.5, 
                  2791.25, 3115.5, 3351, 3301, 3456.25, 3171.5])
ydata3 = np.array([617, 597.5, 599.25, 680, 683.5, 1152.75, 1554.25, 
                  2221.5, 2821.5, 2719.25])
ydata4 = np.array([0.835563087,0.752873171,0.920029517,0.979870724,1.041802752,1.037703103])
ydata5 = np.array([0.756070897,0.714172486,0.878964702,0.950954535,1.027904943,1.045615426])
ydata6 = np.array([0.814900857,0.736160269,0.92669828,1.015810979,1.038236058,1.008212963])
ydata7 = np.array((ydata4+ydata5+ydata6)/3)



def fourPL(x, A, B, C, D):
    return ((A-D)/(1.0+((x/C)**B))) + D
#def fourPL(x,A,B,C,D):
    #y = A/(1+np.exp(-C*(x-B)))+D
    #return y



plt.show()

params, params_covariance = optimization.curve_fit(fourPL,xdata,ydata7)

x_min, x_max = np.amin(xdata), np.amax(xdata)
xs = np.logspace(np.log10(x_min), np.log10(x_max), 100)



fig,ax = plt.subplots(figsize = (15,10))

ax.scatter(xdata, ydata4)
ax.scatter(xdata, ydata5)
ax.scatter(xdata, ydata6)
ax.plot(xs, fourPL(xs, *params),linewidth = 4)
ax.axis([0.0099999999,14,0.2,1.2])

ax.set_xscale('log')
ax.grid()
ax.set_xticks([0.03,0.1,0.3,1,3,10])
from matplotlib.ticker import ScalarFormatter
for axis in [ax.xaxis]:
    axis.set_major_formatter(ScalarFormatter())

plt.show()

# %%
params
# Out:
# array([ 1.01623461, 17.89208863,  1.11638188,  0.76829013])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import scipy.optimize as optimization
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.ticker import ScalarFormatter

xdata = np.array([10,3.3,1.1,0.3,0.1,0.03])
ydata = np.array([591, 648.5, 714.75, 941, 1226, 1768.25, 
                  2232.25, 2716.25, 3056.25, 3034.5])
ydata2 = np.array([595.5, 711, 898.25, 2215.5, 
                  2791.25, 3115.5, 3351, 3301, 3456.25, 3171.5])
ydata3 = np.array([617, 597.5, 599.25, 680, 683.5, 1152.75, 1554.25, 
                  2221.5, 2821.5, 2719.25])
ydata4 = np.array([0.835563087,0.752873171,0.920029517,0.979870724,1.041802752,1.037703103])
ydata5 = np.array([0.756070897,0.714172486,0.878964702,0.950954535,1.027904943,1.045615426])
ydata6 = np.array([0.814900857,0.736160269,0.92669828,1.015810979,1.038236058,1.008212963])
ydata7 = np.array((ydata4+ydata5+ydata6)/3)



def fourPL(x, A, B, C, D):
    return ((A-D)/(1.0+((x/C)**B))) + D
#def fourPL(x,A,B,C,D):
    #y = A/(1+np.exp(-C*(x-B)))+D
    #return y
#def fourPL(x,b,c,d,e):
    '''This function is basically a copy of the LL.4 function from the R drc package with
     - b: hill slope
     - c: min response
     - d: max response
     - e: EC50'''
    
 #   return(c+(d-c)/(1+np.exp(b*(np.log(x)-np.log(e)))))


plt.show()

params, params_covariance = optimization.curve_fit(fourPL,xdata,ydata7)




x_min, x_max = np.amin(xdata), np.amax(xdata)
xs = np.logspace(np.log10(x_min), np.log10(x_max), 100)



fig,ax = plt.subplots(figsize = (10,8))
params[1] = params[1]/3
ax.scatter(xdata, ydata4)
ax.scatter(xdata, ydata5)
ax.scatter(xdata, ydata6)
ax.plot(xs, fourPL(xs, *params),linewidth = 3)
ax.set_xscale('log')

ax.set_xticks([0.03,0.1,0.3,1,3,10])

from matplotlib.ticker import ScalarFormatter
for axis in [ax.xaxis]:
    axis.set_major_formatter(ScalarFormatter())



cell_line = 'K6066'

major_xticks = [0.1,1,10]
major_yticks = [0,0.2,0.4,0.6,0.8,1,1.2]
minor_xticks = [0.03,0.3,3]
minor_yticks = [0.1,0.3,0.5,0.7,0.9,1.1]

ax.set_xticks(minor_xticks, minor=True)
ax.set_xticks(major_xticks)
ax.set_yticks(minor_yticks, minor=True)
ax.set_yticks(major_yticks)
# And a corresponding grid
ax.set_ylabel("Relative Intensity(Cell Titer Glo)")
ax.set_xlabel("Concentration (uM)")
ax.set_title("Cell Line: " + cell_line + '\n' + 'Drug:Erlotnib (Hydrochloride)', fontsize=15,loc = 'left')
ax.grid(which='minor', alpha=0.3, linestyle=':')
ax.grid(which='major', alpha=2)

#plt.savefig('{0}.png'.format("K6066_Erlotnib_EP"), dpi=300, bbox_inches='tight',facecolor='w')
plt.show()

# %%
import scipy.integrate as spi
x = np.logspace(np.log10(x_min), np.log10(x_max), 100)
A,B,C,D = params

y = ((A-D)/(1.0+((x/C)**(B))) + D)
approximation = np.trapz(y,x)
print(approximation)
np.max(y)
total = np.max(y)* (x_max - x_min)
AUC = (approximation/total)
# Out:
# 7.942608004563429

# %%
x_max-x_min
# Out:
# 9.97

# %%
params
# Out:
# array([1.01623461, 5.96402954, 1.11638188, 0.76829013])

# %%
# Out:
#   File "<ipython-input-74-9939f8d9eac5>", line 1
#     *params
#     ^
# SyntaxError: can't use starred expression here

# %%
B = B*3
f = lambda x :((A-D)/(1.0+((x/C)**(B))) + D)

a = x_min; b = x_max; N = 100

# x and y values for the trapezoid rule
x = np.logspace(np.log10(x_min), np.log10(x_max), N)
y = f(x)

# X and Y values for plotting y=f(x)
X = np.logspace(np.log10(x_min), np.log10(x_max), N)
Y = f(x)
plt.plot(X,Y)
plt.xscale('log')


for i in range(N):
    xs = [x[i],x[i],x[i+1],x[i+1]]
    ys = [0,f(x[i]),f(x[i+1]),0]
    plt.fill(xs,ys,'b',edgecolor='b',alpha=0.2)

plt.title('Trapezoid Rule, N = {}'.format(N))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-125-8f6d59269333> in <module>
#      16
#      17 for i in range(N):
# ---> 18     xs = [x[i],x[i],x[i+1],x[i+1]]
#      19     ys = [0,f(x[i]),f(x[i+1]),0]
#      20     plt.fill(xs,ys,'b',edgecolor='b',alpha=0.2)
#
# IndexError: index 100 is out of bounds for axis 0 with size 100

# %%
T = np.trapz(y,x)

# %%
T
# Out:
# 7.942608004563429

# %%
T = trapz(f,a,b,N)
print(T)
# Out:
# 7.942441553816584

# %%
def trapz(f,a,b,N=50):
    '''Approximate the integral of f(x) from a to b by the trapezoid rule.

    The trapezoid rule approximates the integral \int_a^b f(x) dx by the sum:
    (dx/2) \sum_{k=1}^N (f(x_k) + f(x_{k-1}))
    where x_k = a + k*dx and dx = (b - a)/N.

    Parameters
    ----------
    f : function
        Vectorized function of a single variable
    a , b : numbers
        Interval of integration [a,b]
    N : integer
        Number of subintervals of [a,b]

    Returns
    -------
    float
        Approximation of the integral of f(x) from a to b using the
        trapezoid rule with N subintervals of equal length.

    Examples
    --------
    >>> trapz(np.sin,0,np.pi/2,1000)
    0.9999997943832332
    '''
    x = np.linspace(a,b,N+1) # N+1 points make N subintervals
    y = f(x)
    y_right = y[1:] # right endpoints
    y_left = y[:-1] # left endpoints
    dx = (b - a)/N
    T = (dx/2) * np.sum(y_right + y_left)
    return T

# %%
total
# Out:
# 10.131859053766966

# %%
T/total
# Out:
# 0.7953208224041272

# %%
# Out:
# 0.06666666666666667

# %%
x = sy.Symbol('x')
sy.integrate(fourPL(x,*params), (x, x_min,x_max))

# %%
(10-0.03)*1
# Out:
# 9.97

# %%
y_pred = np.array(y_pred)

# %%
P = pd.DataFrame()

# %%
P['x'] = xs

# %%
len(xs)

# %%
len(A)

# %%
P['y'] = A

# %%
P['x'] = round(P['x'],4)

# %%
P[P['x'] > 9.999999]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import scipy.optimize as optimization
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.ticker import ScalarFormatter
import seaborn as sns
xdata = np.array([10,3.3,1.1,0.3,0.1,0.03])
ydata = np.array([591, 648.5, 714.75, 941, 1226, 1768.25, 
                  2232.25, 2716.25, 3056.25, 3034.5])
ydata2 = np.array([595.5, 711, 898.25, 2215.5, 
                  2791.25, 3115.5, 3351, 3301, 3456.25, 3171.5])
ydata3 = np.array([617, 597.5, 599.25, 680, 683.5, 1152.75, 1554.25, 
                  2221.5, 2821.5, 2719.25])
ydata4 = np.array([0.945188246,0.743305421,0.942992152,0.998210103,1.021670171,1.119876329])
ydata5 = np.array([0.921241619,0.699028488,0.859829894,0.862722952,0.879555287,0.88973359])
ydata6 = np.array([0.920531504,0.47342259,0.92183338,0.98751894,0.968911319,1.029691831])
ydata7 = np.array((ydata4+ydata5+ydata6)/3)

cell_line = 'K6066'

def fourPL(x, A, B, C, D):
    return ((A-D)/(1.0+((x/C)**B))) + D
#def fourPL(x,A,B,C,D):
    #y = A/(1+np.exp(-C*(x-B)))+D
    #return y
#def fourPL(x,b,c,d,e):
    '''This function is basically a copy of the LL.4 function from the R drc package with
     - b: hill slope
     - c: min response
     - d: max response
     - e: EC50'''
    
 #   return(c+(d-c)/(1+np.exp(b*(np.log(x)-np.log(e)))))


plt.show()

params, params_covariance = optimization.curve_fit(fourPL,xdata,ydata7)




x_min, x_max = np.amin(xdata), np.amax(xdata)
xs = np.logspace(np.log10(x_min), np.log10(x_max), 100)



fig,ax = plt.subplots(figsize=(10,8))
params[1]= params[1]/3
ax.scatter(xdata, ydata4, label = 'data1')
ax.scatter(xdata, ydata5, label = 'data2')
ax.scatter(xdata, ydata6, label = 'data3')
ax.plot(xs, fourPL(xs, *params),linewidth = 2.5, color = 'blue', label = 'fit')
ax.legend(loc='best')

ax.set_xscale('log')

ax.set_xticks([0.03,0.1,0.3,1,3,10])

from matplotlib.ticker import ScalarFormatter
for axis in [ax.xaxis]:
    axis.set_major_formatter(ScalarFormatter())





major_xticks = [0.1,1,10]
major_yticks = [0,0.2,0.4,0.6,0.8,1,1.2]
minor_xticks = [0.03,0.3,3]
minor_yticks = [0.1,0.3,0.5,0.7,0.9,1.1]

ax.set_xticks(minor_xticks, minor=True)
ax.set_xticks(major_xticks)
ax.set_yticks(minor_yticks, minor=True)
ax.set_yticks(major_yticks)
# And a corresponding grid
ax.set_ylabel("Relative Intensity(Cell Titer Glo)")
ax.set_xlabel("Concentration (uM)")
ax.set_title("Cell Line: " + cell_line + '\n' + 'Drug:ETP-46464', fontsize=15,loc = 'left')
ax.grid(which='minor', alpha=0.3, linestyle=':')
ax.grid(which='major', alpha=2)
x_int = x_min, x_max
#ax.fill_between(xs, fourPL(xs, *params),color = 'pink')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon


def func(x):
    return (x - 3) * (x - 5) * (x - 7) + 85
def func2(x, A, B, C, D):
    return ((A-D)/(1.0+((x/C)**B))) + D


a, b = 0.03, 10  # integral limits
x = xs
y = func2(xs,*params)

fig, ax = plt.subplots()
ax.plot(x, y, 'r', linewidth=2)
ax.set_ylim(bottom=0)

# Make the shaded region

ix = np.linspace(a, b)
iy = func2(ix,*params)
verts = [(a, 0), *zip(ix, iy), (b, 0)]
poly = Polygon(verts, facecolor='0.9', edgecolor='0.5')
ax.add_patch(poly)
ax.xaxis.set_ticks_position('bottom')
ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([])
ax.set_xscale('log')
plt.show()

# %%
len(ix), len(iy)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate
x = np.linspace(-2, 2, num=20)
y = x
y_int = integrate.cumtrapz(y, x, initial=0)
plt.plot(x, y_int, 'ro', x, y[0] + 0.5 * x**2, 'b-')
plt.show()

# %%
testing_int = integrate.cumtrapz(iy, ix, initial = 0)

# %%
plt.plot(ix, testing_int)
plt.xscale('log')
